# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1f2648a-a177-4342-ac43-2df2fe2c939a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1f2648a-a177-4342-ac43-2df2fe2c939a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = next(iter(uploaded))
data = pd.read_csv(filename)
print(f"\n✅ File '{filename}' uploaded successfully.\n")
# Out:
# ✅ File 'da.csv' uploaded successfully.

# %%
print("📄 First 5 Rows of the Dataset:")
display(data.head())
# Out:
# 📄 First 5 Rows of the Dataset:
#    ID  Age  Height  Weight     Sex  Score
# 0   1   25     170      65    Male     88
# 1   2   30     165      70  Female     92
# 2   3   22     175      68    Male     75
# 3   4   28     160      55  Female     85
# 4   5   24     180      72    Male     79

# %%
print("\n📊 Dataset Information:")
print(data.info())
# Out:
# 📊 Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     int64
#  1   Age     10 non-null     int64
#  2   Height  10 non-null     int64
#  3   Weight  10 non-null     int64
#  4   Sex     10 non-null     object
#  5   Score   10 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 612.0+ bytes
# None

# %%
print("\n📊 Dataset Information:")
print(data.info())

print("\n📈 Descriptive Statistics:")
display(data.describe())
# Out:
# 📊 Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     int64
#  1   Age     10 non-null     int64
#  2   Height  10 non-null     int64
#  3   Weight  10 non-null     int64
#  4   Sex     10 non-null     object
#  5   Score   10 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 612.0+ bytes
# None
#
# 📈 Descriptive Statistics:
#              ID        Age      Height     Weight      Score
# count  10.00000  10.000000   10.000000  10.000000  10.000000
# mean    5.50000  25.900000  167.100000  62.900000  84.900000
# std     3.02765   2.601282    6.789698   6.279597   5.566766
# min     1.00000  22.000000  158.000000  54.000000  75.000000
# 25%     3.25000  24.250000  162.500000  58.250000  80.750000
# 50%     5.50000  25.500000  166.500000  63.500000  86.000000
# ...

# %%
print("\n🧼 Checking for Missing and Duplicate Values:")
print("Missing values per column:\n", data.isnull().sum())
print("Duplicate rows:", data.duplicated().sum())
# Out:
# 🧼 Checking for Missing and Duplicate Values:
# Missing values per column:
#  ID        0
# Age       0
# Height    0
# Weight    0
# Sex       0
# Score     0
# dtype: int64
# Duplicate rows: 0

# %%
if data.isnull().sum().sum() > 0:
    data.fillna(method='ffill', inplace=True)
    print("✅ Missing values forward filled.")
else:
    print("✅ No missing values found.")
# Out:
# ✅ No missing values found.

# %%
if data.duplicated().sum() > 0:
    data.drop_duplicates(inplace=True)
    print("✅ Duplicate rows removed.")
else:
    print("✅ No duplicate rows to remove.")
# Out:
# ✅ No duplicate rows to remove.

# %%
if 'Sex' in data.columns:
    data['Sex'] = data['Sex'].map({'Male': 0, 'Female': 1})
    print("\n🔁 Sex column encoded (Male = 0, Female = 1)")
# Out:
# 🔁 Sex column encoded (Male = 0, Female = 1)

# %%
print("\n📦 Boxplots for Numeric Columns:")
numeric_cols = data.select_dtypes(include='number').columns
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=data[col], color='skyblue')
    plt.title(f'Boxplot - {col}', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()
# Out:
# 📦 Boxplots for Numeric Columns:

# %%
print("\n📌 Correlation Heatmap:")
plt.figure(figsize=(8, 6))
sns.heatmap(data[numeric_cols].corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("📈 Correlation Heatmap", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# 📌 Correlation Heatmap:
# /tmp/ipython-input-13-3896331127.py:5: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Note: y_test and y_pred are not defined in the current notebook state.
# Please define these variables before running this cell.

# cm = confusion_matrix(y_test, y_pred)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Low Score", "High Score"])
# disp.plot(cmap='Blues')
# plt.title("📊 Confusion Matrix")
# plt.grid(False)
# plt.show()
